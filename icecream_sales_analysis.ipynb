# %%
import pandas as pd

df = pd.read_csv("icecream_sales_tokyo_utf8_bom.csv")
df.head()
# Out:
#          date  temperature  ice_cream_sales
# 0  2024-06-01         31.5              608
# 1  2024-06-02         29.6              582
# 2  2024-06-03         31.9              626
# 3  2024-06-04         34.6              648
# 4  2024-06-05         29.3              594

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'Hiragino Sans'
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
plt.figure(figsize=(8, 6))

# 回帰直線付き散布図
sns.regplot(data=df, x="temperature", y="ice_cream_sales", scatter_kws={"color": "skyblue"}, line_kws={"color": "red"})

plt.title("気温とアイスクリーム販売数の関係（回帰分析）")
plt.xlabel("気温（℃）")
plt.ylabel("アイス販売数")
plt.grid(True)
plt.show()
